# %% [markdown]
# ## Week 2 HW Linear Basis Regression

# %% [markdown]
# 남승지

# %%
import numpy as np; np.set_printoptions(precision=3)
import pandas as pd; pd.set_option('display.precision',3)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Exploratory Data Analysis

# %% [markdown]
# 데이터 읽어주기

# %%
real = pd.read_csv('real.csv', index_col=0) 
real.columns = ['date','house_age','dist_mrt','no_cvs','lat','long','price']
real
# Out:
#          date  house_age  dist_mrt  no_cvs     lat     long  price
# No
# 1    2012.917       32.0    84.879      10  24.983  121.540   37.9
# 2    2012.917       19.5   306.595       9  24.980  121.540   42.2
# 3    2013.583       13.3   561.985       5  24.987  121.544   47.3
# 4    2013.500       13.3   561.985       5  24.987  121.544   54.8
# 5    2012.833        5.0   390.568       5  24.979  121.542   43.1
# 6    2012.667        7.1  2175.030       3  24.963  121.513   32.1
# 7    2012.667       34.5   623.473       7  24.979  121.536   40.3
# 8    2013.417       20.3   287.603       6  24.980  121.542   46.7
# 9    2013.500       31.7  5512.038       1  24.951  121.485   18.8
# 10   2013.417       17.9  1783.180       3  24.967  121.515   22.1
# 11   2013.083       34.8   405.213       1  24.973  121.534   41.4
# 12   2013.333        6.3    90.456       9  24.974  121.543   58.1
# 13   2012.917       13.0   492.231       5  24.965  121.537   39.3
# 14   2012.667       20.4  2469.645       4  24.961  121.510   23.8
# 15   2013.500       13.2  1164.838       4  24.992  121.534   34.3
# 16   2013.583       35.7   579.208       2  24.982  121.546   50.5
# 17   2013.250        0.0   292.998       6  24.977  121.545   70.1
# 18   2012.750       17.7   350.851       1  24.975  121.531   37.4
# 19   2013.417       16.9   368.136       8  24.968  121.545   42.3
# 20   2012.667        1.5    23.383       7  24.968  121.541   47.7
# 21   2013.417        4.5  2275.877       3  24.963  121.512   29.3
# 22   2013.417       10.5   279.173       7  24.975  121.545   51.6
# 23   2012.917       14.7  1360.139       1  24.952  121.548   24.6
# 24   2013.083       10.1   279.173       7  24.975  121.545   47.9
# 25   2013.000       39.6   480.698       4  24.974  121.539   38.8
# 26   2013.083       29.3  1487.868       2  24.975  121.517   27.0
# 27   2012.667        3.1   383.862       5  24.981  121.544   56.2
# 28   2013.250       10.4   276.449       5  24.956  121.539   33.6
# 29   2013.500       19.2   557.478       4  24.974  121.538   47.0
# 30   2013.083        7.1   451.244       5  24.976  121.547   57.1
# ..        ...        ...       ...     ...     ...      ...    ...
# 385  2012.750       16.1  4066.587       0  24.943  121.503   12.9
# 386  2013.000       18.3    82.886      10  24.983  121.540   46.6
# 387  2012.833        0.0   185.430       0  24.971  121.532   55.3
# 388  2013.250       16.2  2103.555       3  24.960  121.515   25.6
# 389  2013.500       10.4  2251.938       4  24.960  121.514   27.3
# 390  2013.250       40.9   122.362       8  24.968  121.542   67.7
# 391  2013.500       32.8   377.830       9  24.972  121.543   38.6
# 392  2013.583        6.2  1939.749       1  24.952  121.554   31.3
# 393  2013.083       42.7   443.802       6  24.979  121.539   35.3
# 394  2013.000       16.9   967.400       4  24.989  121.534   40.3
# 395  2013.500       32.6  4136.271       1  24.955  121.496   24.7
# 396  2012.917       21.2   512.549       4  24.974  121.538   42.5
# 397  2012.667       37.1   918.636       1  24.972  121.551   31.9
# 398  2013.417       13.1  1164.838       4  24.992  121.534   32.2
# 399  2013.417       14.7  1717.193       2  24.964  121.516   23.0
# 400  2012.917       12.7   170.129       1  24.974  121.530   37.3
# 401  2013.250       26.8   482.758       5  24.974  121.539   35.5
# 402  2013.083        7.6  2175.030       3  24.963  121.513   27.7
# 403  2012.833       12.7   187.482       1  24.974  121.530   28.5
# 404  2012.667       30.9   161.942       9  24.984  121.540   39.7
# 405  2013.333       16.4   289.325       5  24.982  121.543   41.2
# 406  2012.667       23.0   130.994       6  24.957  121.538   37.2
# 407  2013.167        1.9   372.139       7  24.973  121.540   40.5
# 408  2013.000        5.2  2408.993       0  24.955  121.560   22.3
# 409  2013.417       18.5  2175.744       3  24.963  121.512   28.1
# 410  2013.000       13.7  4082.015       0  24.942  121.504   15.4
# 411  2012.667        5.6    90.456       9  24.974  121.543   50.0
# 412  2013.250       18.8   390.970       7  24.979  121.540   40.6
# 413  2013.000        8.1   104.810       5  24.967  121.541   52.5
# 414  2013.500        6.5    90.456       9  24.974  121.543   63.9
#
# [414 rows x 7 columns]

# %% [markdown]
# NA 있는지 확인

# %%
real.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 1 to 414
# Data columns (total 7 columns):
# date         414 non-null float64
# house_age    414 non-null float64
# dist_mrt     414 non-null float64
# no_cvs       414 non-null int64
# lat          414 non-null float64
# long         414 non-null float64
# price        414 non-null float64
# dtypes: float64(6), int64(1)
# memory usage: 25.9 KB

# %% [markdown]
# 거래가 기준으로 정렬

# %%
real.sort_values(by=['price'], inplace=True) 
# by = " " 정렬한 기준 변수
# inplace = True 는 Dataframe 자체를 정렬해서 저장 
real.reset_index(inplace=True) # inplace: replace the original dataset
real = real.drop(['No'], axis=1)
real
# Out:
#          date  house_age  dist_mrt  no_cvs     lat     long  price
# 0    2013.333       14.8   393.261       6  24.962  121.538    7.6
# 1    2013.583       17.4  6488.021       1  24.957  121.474   11.2
# 2    2012.750       16.0  4066.587       0  24.943  121.503   11.6
# 3    2013.000       30.9  6396.283       1  24.944  121.479   12.2
# 4    2013.083       32.0  1156.777       0  24.949  121.530   12.8
# 5    2013.000       16.5  4082.015       0  24.942  121.504   12.8
# 6    2012.750       16.1  4066.587       0  24.943  121.503   12.9
# 7    2013.000       13.6  4197.349       0  24.939  121.504   13.0
# 8    2012.667       29.4  4510.359       1  24.949  121.495   13.2
# 9    2013.417       24.2  4605.749       0  24.947  121.496   13.4
# 10   2012.833       31.7  1160.632       0  24.950  121.530   13.7
# 11   2012.917       31.7  1159.454       0  24.950  121.530   13.8
# 12   2013.333       24.0  4527.687       0  24.947  121.496   14.4
# 13   2012.833       16.2  4074.736       0  24.942  121.504   14.7
# 14   2012.833       18.0  6306.153       1  24.957  121.475   15.0
# 15   2013.000       13.7  4082.015       0  24.942  121.504   15.4
# 16   2012.667       26.9  4449.270       0  24.949  121.496   15.5
# 17   2013.167       13.8  4082.015       0  24.942  121.504   15.6
# 18   2013.333       25.6  4519.690       0  24.948  121.496   15.6
# 19   2013.000       13.6  4082.015       0  24.942  121.504   15.9
# 20   2012.917       31.9  1146.329       0  24.949  121.531   16.1
# 21   2013.333       16.7  4082.015       0  24.942  121.504   16.7
# 22   2012.917       27.1  4412.765       1  24.950  121.496   17.4
# 23   2013.417       31.5  5512.038       1  24.951  121.485   17.4
# 24   2012.917       25.3  2707.392       3  24.961  121.508   17.7
# 25   2013.500       16.8  4066.587       0  24.943  121.503   18.2
# 26   2013.583       16.9  4066.587       0  24.943  121.503   18.3
# 27   2013.583       30.7  1264.730       0  24.949  121.530   18.3
# 28   2012.750       13.5  4197.349       0  24.939  121.504   18.6
# 29   2013.500       31.7  5512.038       1  24.951  121.485   18.8
# ..        ...        ...       ...     ...     ...      ...    ...
# 384  2013.500        8.5   104.810       5  24.967  121.541   56.8
# 385  2013.083        7.1   451.244       5  24.976  121.547   57.1
# 386  2012.917        9.9   279.173       7  24.975  121.545   57.4
# 387  2012.917        3.5    49.661       8  24.958  121.538   57.8
# 388  2013.083        6.2    90.456       9  24.974  121.543   58.0
# 389  2013.583        6.6    90.456       9  24.974  121.543   58.1
# 390  2013.333        6.3    90.456       9  24.974  121.543   58.1
# 391  2013.083        3.6   383.862       5  24.981  121.544   58.8
# 392  2013.583        6.6    90.456       9  24.974  121.543   59.0
# 393  2013.417        6.4    90.456       9  24.974  121.543   59.5
# 394  2013.500       16.6   289.325       5  24.982  121.543   59.6
# 395  2013.250        3.8   383.862       5  24.981  121.544   60.7
# 396  2013.083       41.3   124.991       6  24.967  121.540   60.7
# 397  2013.583       35.9   640.739       3  24.976  121.537   61.5
# 398  2013.167        3.6   373.839      10  24.983  121.538   61.9
# 399  2013.500        4.1    56.474       7  24.957  121.537   62.1
# 400  2013.417        6.4    90.456       9  24.974  121.543   62.2
# 401  2013.083       38.6   804.690       4  24.978  121.535   62.9
# 402  2013.500        5.3   259.661       6  24.976  121.545   63.2
# 403  2013.417        0.0   292.998       6  24.977  121.545   63.3
# 404  2013.083       41.4   281.205       8  24.973  121.541   63.3
# 405  2013.500        6.5    90.456       9  24.974  121.543   63.9
# 406  2013.250       40.9   122.362       8  24.968  121.542   67.7
# 407  2013.333        0.0   292.998       6  24.977  121.545   69.7
# 408  2013.250        0.0   292.998       6  24.977  121.545   70.1
# 409  2012.833        0.0   292.998       6  24.977  121.545   71.0
# 410  2013.417        0.0   292.998       6  24.977  121.545   73.6
# 411  2013.583       35.4   318.529       9  24.971  121.541   78.0
# 412  2013.333       37.2   186.510       9  24.977  121.543   78.3
# 413  2013.333       10.8   252.582       1  24.975  121.530  117.5
#
# [414 rows x 7 columns]

# %% [markdown]
# 거래가 outlier 지워주기

# %%
real.describe()
# Out:
#            date  house_age  dist_mrt   no_cvs      lat     long    price
# count   414.000    414.000   414.000  414.000  414.000  414.000  414.000
# mean   2013.149     17.713  1083.886    4.094   24.969  121.533   37.980
# std       0.282     11.392  1262.110    2.946    0.012    0.015   13.606
# min    2012.667      0.000    23.383    0.000   24.932  121.474    7.600
# 25%    2012.917      9.025   289.325    1.000   24.963  121.528   27.700
# 50%    2013.167     16.100   492.231    4.000   24.971  121.539   38.450
# 75%    2013.417     28.150  1454.279    6.000   24.977  121.543   46.600
# max    2013.583     43.800  6488.021   10.000   25.015  121.566  117.500

# %%
real.hist(bins=50, figsize=(12,10))
plt.tight_layout()

# %%
np.percentile(real.price, 99.5)
# Out:
# 77.71400000000001

# %%
real = real[real.price < 80]
plt.hist(real.price, bins=50)
plt.tight_layout()

# %% [markdown]
# 변수 간의 관계를 보면서 변환 해야할까 결정하기

# %%
sns.pairplot(real[['dist_mrt', 'house_age','no_cvs','price']])

# %% [markdown]
# `dist_mrt` 변수가 skew 가 심하므로 log를 취해주자

# %%
real2 = real.copy()
real2['dist_mrt'] = np.log(1+real.dist_mrt) # to prevent inf
sns.pairplot(real2[['dist_mrt', 'house_age','no_cvs','price']])

# %% [markdown]
# `dist_mrt` 변수가 종모양이 되었고, 다른 변수와의 관계도 대략 선형관계처럼 보인다.

# %% [markdown]
# ### 1. test set 추출

# %%
N = real.shape[0]

# %%
X = pd.DataFrame(real[["house_age", "dist_mrt", "no_cvs"]])
# drop axis의 경우 column 이면 1, row 이면 0
Y = pd.DataFrame(real['price'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 730)

# %%
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)
Y_train.reset_index(drop=True, inplace=True)
Y_test.reset_index(drop=True, inplace=True)

# %%
Y_train = Y_train['price'].tolist()
Y_test = Y_test['price'].tolist()

# %% [markdown]
# ### 2. Feature Extraction

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# degree를 2차랑 3차일때 test set으로 mse 를 계산해보자

# %%
poly2 = PolynomialFeatures(degree=2)
X_train_poly2 = poly2.fit_transform(X_train)
X_test_poly2 = poly2.fit_transform(X_test)
X_train_poly2.shape
# Out:
# (289, 10)

# %%
lin2 = LinearRegression(fit_intercept= False)
lin2.fit(X_train_poly2, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=False, n_jobs=None, normalize=False)

# %%
mean_squared_error(Y_test,lin2.predict(X_test_poly2))
# Out:
# 54.48471170385281

# %%
poly3 = PolynomialFeatures(degree=3)
X_train_poly3 = poly3.fit_transform(X_train)
X_test_poly3 = poly3.fit_transform(X_test)
X_train_poly3.shape
# Out:
# (289, 20)

# %%
lin3 = LinearRegression(fit_intercept= False)
lin3.fit(X_train_poly3, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=False, n_jobs=None, normalize=False)

# %%
mean_squared_error(Y_test,lin3.predict(X_test_poly3))
# Out:
# 52.21031734292783

# %% [markdown]
# degree가 3차일때보다 2차일때 mse 가 작다. degree = 2로 모델을 만들어보자

# %% [markdown]
# ### 3. Ridge, Lasso Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %% [markdown]
# linear regression

# %%
lin = LinearRegression()
lin.fit(X_train_poly2, Y_train)
pre_lin_train = lin.predict(X_train_poly2)
pre_lin_test = lin.predict(X_test_poly2)
lin_trainmse = mean_squared_error(Y_train, pre_lin_train)
lin_testmse = mean_squared_error(Y_test, pre_lin_test)
print(lin_trainmse); print(lin_testmse)
# Out:
# 57.284827384230745
# 54.48471170329826

# %% [markdown]
# Ridge Regression

# %%
alphas = [0.1, 0.5, 1, 10]

# %%
rdg_trainmse = []
rdg_testmse = []
for i in alphas :
    rdg = Ridge(alpha = i, normalize = True)
    rdg.fit(X_train_poly2, Y_train)
    pre_rdg_train = rdg.predict(X_train_poly2)
    pre_rdg_test = rdg.predict(X_test_poly2)
    rdg_trainmse.append(mean_squared_error(Y_train, pre_rdg_train))
    rdg_testmse.append(mean_squared_error(Y_test, pre_rdg_test))
print(rdg_trainmse); print(rdg_testmse)
# Out:
# [66.09672784503408, 74.92405101771047, 80.61884352573372, 134.36273226033614]
# [58.126335353761185, 63.50523026015101, 66.11851768347249, 101.62960524608135]

# %% [markdown]
# Lasso Regression

# %%
las_trainmse = []
las_testmse = []
for i in alphas :
    las = Lasso(alpha = i, normalize = True)
    las.fit(X_train_poly2, Y_train)
    pre_las_train = las.predict(X_train_poly2)
    pre_las_test = las.predict(X_test_poly2)
    las_trainmse.append(mean_squared_error(Y_train, pre_las_train))
    las_testmse.append(mean_squared_error(Y_test, pre_las_test))
print(las_trainmse); print(las_testmse)
# Out:
# [76.46926360117074, 164.87435380696505, 183.02819075442102, 183.02819075442102]
# [63.573831329720655, 125.51714321850399, 139.1495779697669, 139.1495779697669]

# %% [markdown]
# mse 비교

# %%
print(lin_trainmse); print(lin_testmse)
print(rdg_trainmse); print(rdg_testmse)
print(las_trainmse); print(las_testmse)
# Out:
# 57.284827384230745
# 54.48471170329826
# [66.09672784503408, 74.92405101771047, 80.61884352573372, 134.36273226033614]
# [58.126335353761185, 63.50523026015101, 66.11851768347249, 101.62960524608135]
# [76.46926360117074, 164.87435380696505, 183.02819075442102, 183.02819075442102]
# [63.573831329720655, 125.51714321850399, 139.1495779697669, 139.1495779697669]

# %% [markdown]
# 계수 비교 (alpha = 0.1)

# %%
print(lin.coef_)
rid1 = Ridge(alpha= 0.1, normalize = True)
rid1.fit(X_train_poly2, Y_train)
print(rid1.coef_)
las1= Lasso(alpha = 0.1, normalize = True)
las1.fit(X_train_poly2, Y_train)
print(las1.coef_)
# Out:
# [ 0.000e+00 -1.099e+00 -8.058e-03  3.138e+00  1.725e-02  1.041e-04
#   1.575e-02  5.959e-07 -1.273e-03 -1.908e-01]
# [ 0.000e+00 -3.576e-01 -3.879e-03  1.581e+00  3.236e-03 -8.544e-06
#  -1.724e-03  3.079e-08 -1.050e-03  2.837e-02]
# [ 0.000e+00 -1.249e-01 -4.091e-03  1.249e+00 -0.000e+00 -0.000e+00
#  -0.000e+00 -0.000e+00 -2.877e-04  0.000e+00]

# %% [markdown]
# ### 4. k- fold CV sampling

# %%
import numpy as np
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.model_selection import KFold

# %%
print(X_train_poly2.shape)
print(X_test_poly2.shape)
# Out:
# (289, 10)
# (124, 10)

# %%
alphas = np.logspace(-6 ,6, 500)

# %%
rdgcv = RidgeCV(alphas = alphas, normalize= True,cv = 5)
rdgcv.fit(X_train_poly2,Y_train)
rdg_alpha_best = rdgcv.alpha_
rdg_alpha_best
# Out:
# 0.0032435608072358115

# %% [markdown]
# ridge 알파계수는 0

# %%
lascv = LassoCV(alphas = alphas, normalize = True, cv =5)
lascv.fit(X_train_poly2, Y_train)
las_alpha_best = lascv.alpha_
las_alpha_best
# Out:
# 1e-06

# %%
rdg = Ridge(alpha = rdg_alpha_best, normalize = True)
rdg.fit(X_train_poly2, Y_train)
pre_rdg_train = rdg.predict(X_train_poly2)
pre_rdg_test = rdg.predict(X_test_poly2)
print(mean_squared_error(Y_train, pre_rdg_train))
rdg_best_testmse = mean_squared_error(Y_test, pre_rdg_test)
print(rdg_best_testmse)
# Out:
# 57.384076112941415
# 53.951084455899824

# %%
las = Lasso(alpha = las_alpha_best, normalize = True)
las.fit(X_train_poly2, Y_train)
pre_las_train = las.predict(X_train_poly2)
pre_las_test = las.predict(X_test_poly2)
print(mean_squared_error(Y_train, pre_las_train))
las_best_testmse = mean_squared_error(Y_test, pre_las_test)
print(las_best_testmse)
# Out:
# 57.28482744168397
# 54.48410481566425

# %%
print(lin_testmse); print(rdg_best_testmse); print(las_best_testmse)
# Out:
# 54.48471170329826
# 53.951084455899824
# 54.48410481566425

# %% [markdown]
# ### 5. test mse 보고, 어떤 feature 선택

# %%
print(lin_testmse); print(rdg_best_testmse); print(las_best_testmse)
# Out:
# 54.48471170329826
# 53.951084455899824
# 54.48410481566425

# %% [markdown]
# 2차로 fitting 했을 때, ridge regression model의 test mse가 가장 작지만, ridge, lasso, linear regression 세가지 모두 test mse가 비슷하여, penalty 없이 linear regression model을 써도 될 것 같다.
