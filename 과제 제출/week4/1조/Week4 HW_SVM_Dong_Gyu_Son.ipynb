# %% [markdown]
# # Week 4 HW : Support Vector Machine

# %% [markdown]
# ## 1. Multiclass SVM : iris dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets

# %%
iris = datasets.load_iris()
X = iris.data[:, :2]
y = iris.target

# %%
C = 1
svc = svm.SVC(kernel = 'linear', C = 1, gamma = 'auto').fit(X, y)

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
h = (x_max / x_min) / 100
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# %%
plt.subplot(1, 1, 1)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap = plt.cm.Paired, alpha = 0.8)
plt.scatter(X[:, 0], X[:, 1], c = y, cmap = plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal Width')
plt.xlim(xx.min(), xx.max())
plt.title('SVC with linear kernel')
plt.show()

# %%
svc = svm.SVC(kernel = 'rbf', C =1, gamma = 'auto').fit(X, y)

# %%
plt.subplot(1, 1, 1)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap = plt.cm.Paired, alpha = 0.8)
plt.scatter(X[:, 0], X[:, 1], c = y, cmap = plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal Width')
plt.xlim(xx.min(), xx.max())
plt.title('SVC with rbf kernel')
plt.show()

# %%
fig = plt.figure(figsize=(20, 5))

svc = svm.SVC(kernel = 'rbf', C =1, gamma = 1).fit(X, y)
a1 = fig.add_subplot(131)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
a1.contourf(xx, yy, Z, cmap = plt.cm.Paired, alpha = 0.8)
a1.scatter(X[:, 0], X[:, 1], c = y, cmap = plt.cm.Paired)
a1.set_xlabel('Sepal length')
a1.set_ylabel('Sepal Width')
a1.set_xlim(xx.min(), xx.max())
a1.set_title('SVC with rbf kernel, C = 1, gamma = 1')

svc = svm.SVC(kernel = 'rbf', C =1, gamma = 10).fit(X, y)
a2 = fig.add_subplot(132)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
a2.contourf(xx, yy, Z, cmap = plt.cm.Paired, alpha = 0.8)
a2.scatter(X[:, 0], X[:, 1], c = y, cmap = plt.cm.Paired)
a2.set_xlabel('Sepal length')
a2.set_ylabel('Sepal Width')
a2.set_xlim(xx.min(), xx.max())
a2.set_title('SVC with rbf kernel, C = 1, gamma = 10')

svc = svm.SVC(kernel = 'rbf', C =1, gamma = 100).fit(X, y)
a3 = fig.add_subplot(133)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
a3.contourf(xx, yy, Z, cmap = plt.cm.Paired, alpha = 0.8)
a3.scatter(X[:, 0], X[:, 1], c = y, cmap = plt.cm.Paired)
a3.set_xlabel('Sepal length')
a3.set_ylabel('Sepal Width')
a3.set_xlim(xx.min(), xx.max())
a3.set_title('SVC with rbf kernel, C = 1, gamma = 100')
# Out:
# Text(0.5, 1.0, 'SVC with rbf kernel, C = 1, gamma = 100')

# %%
fig = plt.figure(figsize=(20, 5))

svc = svm.SVC(kernel = 'rbf', C =1, gamma = 'auto').fit(X, y)
b1 = fig.add_subplot(131)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
b1.contourf(xx, yy, Z, cmap = plt.cm.Paired, alpha = 0.8)
b1.scatter(X[:, 0], X[:, 1], c = y, cmap = plt.cm.Paired)
b1.set_xlabel('Sepal length')
b1.set_ylabel('Sepal Width')
b1.set_xlim(xx.min(), xx.max())
b1.set_title('SVC with rbf kernel, C = 1, gamma = auto')

svc = svm.SVC(kernel = 'rbf', C =100, gamma = 'auto').fit(X, y)
b2 = fig.add_subplot(132)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
b2.contourf(xx, yy, Z, cmap = plt.cm.Paired, alpha = 0.8)
b2.scatter(X[:, 0], X[:, 1], c = y, cmap = plt.cm.Paired)
b2.set_xlabel('Sepal length')
b2.set_ylabel('Sepal Width')
b2.set_xlim(xx.min(), xx.max())
b2.set_title('SVC with rbf kernel, C = 100, gamma = auto')

svc = svm.SVC(kernel = 'rbf', C =10000, gamma = 'auto').fit(X, y)
b3 = fig.add_subplot(133)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
b3.contourf(xx, yy, Z, cmap = plt.cm.Paired, alpha = 0.8)
b3.scatter(X[:, 0], X[:, 1], c = y, cmap = plt.cm.Paired)
b3.set_xlabel('Sepal length')
b3.set_ylabel('Sepal Width')
b3.set_xlim(xx.min(), xx.max())
b3.set_title('SVC with rbf kernel, C = 10000, gamma = auto')
# Out:
# Text(0.5, 1.0, 'SVC with rbf kernel, C = 10000, gamma = auto')

# %% [markdown]
# ## 2. Weighted SVM : toy dataset

# %% [markdown]
# ### (1) Imbalanced Classification Dataset

# %%
from sklearn.datasets import make_classification
from collections import Counter

# %%
X, y = make_classification(n_samples = 10000, n_features = 2, n_redundant = 0,
                          n_clusters_per_class = 1, weights = [0.99], flip_y = 0, random_state = 4)

# %%
plt.scatter(X[:, 0], X[:, 1], c = y, s= 50, cmap = 'summer')

# %%
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 9900, 1: 100})

# %%
for label, _ in counter.items():
    row_ix = np.where(y == label)[0]
    plt.scatter(X[row_ix, 0], X[row_ix, 1], label = str(label))
plt.legend()
plt.show()

# %%
from sklearn.model_selection import cross_val_score as cvs, RepeatedStratifiedKFold as RSKFold
from sklearn.svm import SVC

# %%
model = SVC(gamma = 'scale').fit(X, y)

# %%
cv = RSKFold(n_splits = 10, n_repeats = 3, random_state = 1)
scores = cvs(model, X, y, scoring = 'roc_auc', cv = cv, n_jobs = -1)
print( 'Mean ROC AUC : %.3f' %np.mean(scores))
# Out:
# Mean ROC AUC : 0.804

# %%
def plot_svc_decision_function(model, ax=None, plot_support=True):
    if ax is None:
        ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    x = np.linspace(xlim[0], xlim[1], 30)
    y = np.linspace(ylim[0], ylim[1], 30)
    Y, X = np.meshgrid(y, x)
    xy = np.vstack([X.ravel(), Y.ravel()]).T
    P = model.decision_function(xy).reshape(X.shape)
    
    ax.contour(X, Y, P, colors='k',
               levels=[-1, 0, 1], alpha=0.5,
               linestyles=['--', '-', '--'])
    
    if plot_support:
        ax.scatter(model.support_vectors_[:, 0],
                   model.support_vectors_[:, 1],
                   s=300, linewidth=1, facecolors='none')
    
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

# %%
for label, _ in counter.items():
    row_ix = np.where(y == label)[0]
    plt.scatter(X[row_ix, 0], X[row_ix, 1], label = str(label))
plt.legend()
plot_svc_decision_function(model)
plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1],
           s =300, lw =1, facecolors = 'none')

# %% [markdown]
# ### (2) Weighted SVM with Scikit-Learn

# %%
weights = {0:1, 1:100}
model = SVC(gamma = 'scale', class_weight = weights).fit(X, y)

for label, _ in counter.items():
    row_ix = np.where(y == label)[0]
    plt.scatter(X[row_ix, 0], X[row_ix, 1], label = str(label))
plot_svc_decision_function(model)
plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1],
           s =300, lw =1, facecolors = 'none')

# %%
model = SVC(gamma = 'scale', class_weight = 'balanced').fit(X, y)

for label, _ in counter.items():
    row_ix = np.where(y == label)[0]
    plt.scatter(X[row_ix, 0], X[row_ix, 1], label = str(label))
plot_svc_decision_function(model)
plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1],
           s =300, lw =1, facecolors = 'none')

# %%
cv = RSKFold(n_splits = 10, n_repeats = 3, random_state = 1)
scores = cvs(model, X, y, scoring = 'roc_auc', cv = cv, n_jobs = -1)
print( 'Mean ROC AUC : %.3f' %np.mean(scores))
# Out:
# Mean ROC AUC : 0.964

# %% [markdown]
# ### (3) Grid Search Weighted SVM

# %%
balance = [{0:100, 1:1}, {0:10, 1:1}, {0:1, 1:1}, {0:1, 1:10}, {0:1, 1:100}]
param_grid = dict(class_weight = balance)

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, n_jobs = -1, cv = cv, scoring = 'roc_auc')

# %%
grid_result = grid.fit(X, y)
print("Best: %f using %s" %(grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.966189 using {'class_weight': {0: 1, 1: 100}}

# %%
means = grid_result.cv_results_["mean_test_score"]
stds = grid_result.cv_results_["std_test_score"]
params = grid_result.cv_results_["params"]
for mean, stdev, param in zip(means, stds, params):
    print("%f(%f) with : %r" % (mean, stdev, param))
# Out:
# 0.745249(0.129002) with : {'class_weight': {0: 100, 1: 1}}
# 0.748407(0.128049) with : {'class_weight': {0: 10, 1: 1}}
# 0.803727(0.103536) with : {'class_weight': {0: 1, 1: 1}}
# 0.932620(0.059869) with : {'class_weight': {0: 1, 1: 10}}
# 0.966189(0.036310) with : {'class_weight': {0: 1, 1: 100}}
