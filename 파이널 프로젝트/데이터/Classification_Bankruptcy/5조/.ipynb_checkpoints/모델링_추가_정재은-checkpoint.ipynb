# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("imputed_final_deleted.csv")
df.shape
# Out:
# (6835, 31)

# %%
y = df['class']
X = df[df.columns[df.columns != 'class']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=5)

# %% [markdown]
# # 1. Evaluation
# # 1-1. Train set

# %%
import pickle 
import joblib
import warnings

warnings.filterwarnings('ignore')

# %%
# ensemble method

lr_clf = joblib.load('logistic.pkl')
svm_clf = joblib.load('SVM_linear.pkl')
rf_clf = joblib.load('forest_01.pkl')
xgb_clf = pickle.load(open('xgb.pkl', 'rb'))

scores = pickle.load(open('scores.pkl', 'rb'))

lr_probs = lr_clf.predict_proba(X)
svm_probs = svm_clf.predict_proba(X)
rf_probs = rf_clf.predict_proba(X)
xgb_probs = xgb_clf.predict_proba(X)

def predict():
    y_pred = np.empty(shape=(X.shape[0], ), dtype=np.int)
    for i in range(len(y_pred)):
        pos = lr_probs[i, 1] * scores[0] + svm_probs[i, 1] * scores[1] + rf_probs[i, 1] * scores[2] + xgb_probs[i, 1] * scores[3]
        neg = lr_probs[i, 0] * scores[0] + svm_probs[i, 0] * scores[1] + rf_probs[i, 0] * scores[2] + xgb_probs[i, 0] * scores[3]
        if pos > neg:
            y_pred[i] = 1
        else:
            y_pred[i] = 0

    y_pred = pd.DataFrame(y_pred)
    return y_pred
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-9-b8cf58395d18> in <module>
#       4 svm_clf = joblib.load('SVM_linear.pkl')
#       5 rf_clf = joblib.load('forest_01.pkl')
# ----> 6 xgb_clf = pickle.load(open('xgb.pkl', 'rb'))
#       7
#       8 scores = pickle.load(open('scores.pkl', 'rb'))
#
# ~\Desktop\anaconda\envs\test\lib\site-packages\xgboost\core.py in __setstate__(self, state)
#    1210             ptr = (ctypes.c_char * len(buf)).from_buffer(buf)
#    1211             _check_call(
# -> 1212                 _LIB.XGBoosterUnserializeFromBuffer(handle, ptr, length))
#    1213             state['handle'] = handle
#    1214         self.__dict__.update(state)
#
# ~\Desktop\anaconda\envs\test\lib\site-packages\xgboost\core.py in _check_call(ret)
#     188     """
#     189     if ret != 0:
# --> 190         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     191
#     192
#
# XGBoostError: [11:04:46] C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:846: Check failed: header == serialisation_header_:
#
#   If you are loading a serialized model (like pickle in Python) generated by older
#   XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version.  There's a simple script for helping
#   the process. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for reference to the script, and more details about differences between saving model and
#   serializing.
